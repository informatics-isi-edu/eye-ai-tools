# %% [markdown]
# <a href="https://colab.research.google.com/github/informatics-isi-edu/eye-ai-tools/blob/main/notebooks/Eye_ai_get_cropped_image.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Prerequisites
# !pip install --upgrade --force pydantic git+https://github.com/fair-research/bdbag git+https://github.com/informatics-isi-edu/deriva-py git+https://github.com/informatics-isi-edu/eye-ai-tools git+https://github.com/informatics-isi-edu/deriva-ml git+https://github.com/informatics-isi-edu/eye-ai-ml
import json
import os
from eye_ai import EyeAI
import pandas as pd
from pathlib import Path, PurePath
import logging
# Out:
# Collecting git+https://github.com/fair-research/bdbag
#   Cloning https://github.com/fair-research/bdbag to /tmp/pip-req-build-tocbwwq4
#   Running command git clone --filter=blob:none --quiet https://github.com/fair-research/bdbag /tmp/pip-req-build-tocbwwq4
#   Resolved https://github.com/fair-research/bdbag to commit d3e7d7855ac61c9b46891d2c6e49b988e21baeb3
#   Preparing metadata (setup.py) ... done
# Collecting git+https://github.com/informatics-isi-edu/deriva-py
#   Cloning https://github.com/informatics-isi-edu/deriva-py to /tmp/pip-req-build-43ttv4j1
#   Running command git clone --filter=blob:none --quiet https://github.com/informatics-isi-edu/deriva-py /tmp/pip-req-build-43ttv4j1
#   Resolved https://github.com/informatics-isi-edu/deriva-py to commit 7335843c5a990162b7d91fe3361d273cd73ba848
#   Preparing metadata (setup.py) ... done
# Collecting git+https://github.com/informatics-isi-edu/eye-ai-tools
#   Cloning https://github.com/informatics-isi-edu/eye-ai-tools to /tmp/pip-req-build-lpbsb1j6
#   Running command git clone --filter=blob:none --quiet https://github.com/informatics-isi-edu/eye-ai-tools /tmp/pip-req-build-lpbsb1j6
#   Resolved https://github.com/informatics-isi-edu/eye-ai-tools to commit 3c461bd45f63278eef7c613decc78e1733f4ba88
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting git+https://github.com/informatics-isi-edu/deriva-ml
#   Cloning https://github.com/informatics-isi-edu/deriva-ml to /tmp/pip-req-build-lzssi63q
#   Running command git clone --filter=blob:none --quiet https://github.com/informatics-isi-edu/deriva-ml /tmp/pip-req-build-lzssi63q
#   Resolved https://github.com/informatics-isi-edu/deriva-ml to commit 93ccd0cb022c858519124e758b874cf00d3c1f71
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting git+https://github.com/informatics-isi-edu/eye-ai-ml
#   Cloning https://github.com/informatics-isi-edu/eye-ai-ml to /tmp/pip-req-build-qgv38xxf
#   Running command git clone --filter=blob:none --quiet https://github.com/informatics-isi-edu/eye-ai-ml /tmp/pip-req-build-qgv38xxf
#   Resolved https://github.com/informatics-isi-edu/eye-ai-ml to commit 9a07c30886957e425f674d94f1e05286ff54380a
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting pydantic
#   Using cached pydantic-2.6.1-py3-none-any.whl (394 kB)
# Collecting annotated-types>=0.4.0 (from pydantic)
#   Using cached annotated_types-0.6.0-py3-none-any.whl (12 kB)
# Collecting pydantic-core==2.16.2 (from pydantic)
#   Using cached pydantic_core-2.16.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
# Collecting typing-extensions>=4.6.1 (from pydantic)
#   Using cached typing_extensions-4.9.0-py3-none-any.whl (32 kB)
# Collecting pytz (from bdbag==1.7.2)
#   Using cached pytz-2024.1-py2.py3-none-any.whl (505 kB)
# Collecting tzlocal (from bdbag==1.7.2)
#   Using cached tzlocal-5.2-py3-none-any.whl (17 kB)
# Collecting certifi (from bdbag==1.7.2)
#   Using cached certifi-2024.2.2-py3-none-any.whl (163 kB)
# Collecting packaging (from bdbag==1.7.2)
#   Using cached packaging-23.2-py3-none-any.whl (53 kB)
# Collecting requests>=2.7.0 (from bdbag==1.7.2)
#   Using cached requests-2.31.0-py3-none-any.whl (62 kB)
# Collecting setuptools_scm<6.0 (from bdbag==1.7.2)
#   Using cached setuptools_scm-5.0.2-py2.py3-none-any.whl (29 kB)
# Collecting bagit==1.8.1 (from bdbag==1.7.2)
#   Using cached bagit-1.8.1-py2.py3-none-any.whl (35 kB)
# Collecting bagit-profile==1.3.1 (from bdbag==1.7.2)
#   Using cached bagit_profile-1.3.1-py3-none-any.whl (14 kB)
# Collecting setuptools>=20.2 (from deriva==1.6.4)
#   Using cached setuptools-69.1.0-py3-none-any.whl (819 kB)
# Collecting pika (from deriva==1.6.4)
#   Using cached pika-1.3.2-py3-none-any.whl (155 kB)
# Collecting urllib3<2.0,>=1.26.0 (from deriva==1.6.4)
#   Using cached urllib3-1.26.18-py2.py3-none-any.whl (143 kB)
# Collecting portalocker>=1.2.1 (from deriva==1.6.4)
#   Using cached portalocker-2.8.2-py3-none-any.whl (17 kB)
# Collecting globus_sdk<4,>=3 (from deriva==1.6.4)
#   Using cached globus_sdk-3.37.0-py3-none-any.whl (299 kB)
# Collecting fair-research-login>=0.3.1 (from deriva==1.6.4)
#   Using cached fair_research_login-0.3.1-py3-none-any.whl (39 kB)
# Collecting fair-identifiers-client>=0.5.1 (from deriva==1.6.4)
#   Using cached fair_identifiers_client-0.5.1-py3-none-any.whl (45 kB)
# Collecting jsonschema>=3.1 (from deriva==1.6.4)
#   Using cached jsonschema-4.21.1-py3-none-any.whl (85 kB)
# Collecting six<2.0.0,>=1.10.0 (from fair-identifiers-client>=0.5.1->deriva==1.6.4)
#   Using cached six-1.16.0-py2.py3-none-any.whl (11 kB)
# Collecting pyjwt[crypto]<3.0.0,>=2.0.0 (from globus_sdk<4,>=3->deriva==1.6.4)
#   Using cached PyJWT-2.8.0-py3-none-any.whl (22 kB)
# Collecting cryptography!=3.4.0,>=3.3.1 (from globus_sdk<4,>=3->deriva==1.6.4)
#   Using cached cryptography-42.0.3-cp39-abi3-manylinux_2_28_x86_64.whl (4.6 MB)
# Collecting attrs>=22.2.0 (from jsonschema>=3.1->deriva==1.6.4)
#   Using cached attrs-23.2.0-py3-none-any.whl (60 kB)
# Collecting jsonschema-specifications>=2023.03.6 (from jsonschema>=3.1->deriva==1.6.4)
#   Using cached jsonschema_specifications-2023.12.1-py3-none-any.whl (18 kB)
# Collecting referencing>=0.28.4 (from jsonschema>=3.1->deriva==1.6.4)
#   Using cached referencing-0.33.0-py3-none-any.whl (26 kB)
# Collecting rpds-py>=0.7.1 (from jsonschema>=3.1->deriva==1.6.4)
#   Using cached rpds_py-0.18.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
# Collecting charset-normalizer<4,>=2 (from requests>=2.7.0->bdbag==1.7.2)
#   Using cached charset_normalizer-3.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (142 kB)
# Collecting idna<4,>=2.5 (from requests>=2.7.0->bdbag==1.7.2)
#   Using cached idna-3.6-py3-none-any.whl (61 kB)
# Collecting cffi>=1.12 (from cryptography!=3.4.0,>=3.3.1->globus_sdk<4,>=3->deriva==1.6.4)
#   Using cached cffi-1.16.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (443 kB)
# Collecting pycparser (from cffi>=1.12->cryptography!=3.4.0,>=3.3.1->globus_sdk<4,>=3->deriva==1.6.4)
#   Using cached pycparser-2.21-py2.py3-none-any.whl (118 kB)
# Building wheels for collected packages: bdbag, deriva, eye-ai, deriva-ml, eye-ai-ml
#   Building wheel for bdbag (setup.py) ... done
#   Created wheel for bdbag: filename=bdbag-1.7.2-py2.py3-none-any.whl size=74890 sha256=907e5fdb8c0598012faa8126d9dec4eeaa6e46d1b7257ac868ffb9f34d60fe46
#   Stored in directory: /tmp/pip-ephem-wheel-cache-83gow5xt/wheels/e6/37/a1/ed335483cf88440ed32b8f918cc20fa31b2ee2c81dd9504f7a
#   Building wheel for deriva (setup.py) ... done
#   Created wheel for deriva: filename=deriva-1.6.4-py2.py3-none-any.whl size=213709 sha256=ae09024421fa17c74c2faab3df1137e3ebaa53d607a1377a93aa1ff967a6fb06
#   Stored in directory: /tmp/pip-ephem-wheel-cache-83gow5xt/wheels/f5/4a/e4/12bf545b4525249722e860b95e934babd35df222684152f80d
#   Building wheel for eye-ai (pyproject.toml) ... done
#   Created wheel for eye-ai: filename=eye_ai-0.0.1-py3-none-any.whl size=9185 sha256=56596d5a3eabd396613f16579b75c1a4e8bceaa5ae6a57df05a3ef1dbd2b31d6
#   Stored in directory: /tmp/pip-ephem-wheel-cache-83gow5xt/wheels/b8/3d/ee/56cb93f0a37d21370f4ad75a02619f63503d0ba0c6987ccf30
#   Building wheel for deriva-ml (pyproject.toml) ... done
#   Created wheel for deriva-ml: filename=deriva_ml-0.0.1-py3-none-any.whl size=13734 sha256=5b94277ca6af6ee165f0eba452b133e32acbdc3616deee093942b98ecdf82bba
#   Stored in directory: /tmp/pip-ephem-wheel-cache-83gow5xt/wheels/5e/44/fc/69aec1f5d3789673392eb399c637044c66aa264ce8ec4b43a7
#   Building wheel for eye-ai-ml (pyproject.toml) ... done
#   Created wheel for eye-ai-ml: filename=eye_ai_ml-0.0.1-py3-none-any.whl size=11587 sha256=93a2c02e594b2f6333a15a7440bc385d9dd7d6a4aa21245c24ec0ae1714b2ff0
#   Stored in directory: /tmp/pip-ephem-wheel-cache-83gow5xt/wheels/1e/7f/76/67bd42d2c427a39149e1ebd833d93bd7aad1b774daba1f8c07
# Successfully built bdbag deriva eye-ai deriva-ml eye-ai-ml
# Installing collected packages: pytz, bagit, urllib3, tzlocal, typing-extensions, six, setuptools, rpds-py, pyjwt, pycparser, portalocker, pika, packaging, idna, eye-ai-ml, eye-ai, deriva-ml, charset-normalizer, certifi, attrs, annotated-types, setuptools_scm, requests, referencing, pydantic-core, cffi, pydantic, jsonschema-specifications, cryptography, bagit-profile, jsonschema, bdbag, globus_sdk, fair-research-login, fair-identifiers-client, deriva
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2024.1
#     Uninstalling pytz-2024.1:
#       Successfully uninstalled pytz-2024.1
#   Attempting uninstall: bagit
#     Found existing installation: bagit 1.8.1
#     Uninstalling bagit-1.8.1:
#       Successfully uninstalled bagit-1.8.1
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.26.18
#     Uninstalling urllib3-1.26.18:
#       Successfully uninstalled urllib3-1.26.18
#   Attempting uninstall: tzlocal
#     Found existing installation: tzlocal 5.2
#     Uninstalling tzlocal-5.2:
#       Successfully uninstalled tzlocal-5.2
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.9.0
#     Uninstalling typing_extensions-4.9.0:
#       Successfully uninstalled typing_extensions-4.9.0
#   Attempting uninstall: six
#     Found existing installation: six 1.16.0
#     Uninstalling six-1.16.0:
#       Successfully uninstalled six-1.16.0
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 69.1.0
#     Uninstalling setuptools-69.1.0:
#       Successfully uninstalled setuptools-69.1.0
#   Attempting uninstall: rpds-py
#     Found existing installation: rpds-py 0.18.0
#     Uninstalling rpds-py-0.18.0:
#       Successfully uninstalled rpds-py-0.18.0
#   Attempting uninstall: pyjwt
#     Found existing installation: PyJWT 2.8.0
#     Uninstalling PyJWT-2.8.0:
#       Successfully uninstalled PyJWT-2.8.0
#   Attempting uninstall: pycparser
#     Found existing installation: pycparser 2.21
#     Uninstalling pycparser-2.21:
#       Successfully uninstalled pycparser-2.21
#   Attempting uninstall: portalocker
#     Found existing installation: portalocker 2.8.2
#     Uninstalling portalocker-2.8.2:
#       Successfully uninstalled portalocker-2.8.2
#   Attempting uninstall: pika
#     Found existing installation: pika 1.3.2
#     Uninstalling pika-1.3.2:
#       Successfully uninstalled pika-1.3.2
#   Attempting uninstall: packaging
#     Found existing installation: packaging 23.2
#     Uninstalling packaging-23.2:
#       Successfully uninstalled packaging-23.2
#   Attempting uninstall: idna
#     Found existing installation: idna 3.6
#     Uninstalling idna-3.6:
#       Successfully uninstalled idna-3.6
#   Attempting uninstall: eye-ai-ml
#     Found existing installation: eye-ai-ml 0.0.1
#     Uninstalling eye-ai-ml-0.0.1:
#       Successfully uninstalled eye-ai-ml-0.0.1
#   Attempting uninstall: eye-ai
#     Found existing installation: eye-ai 0.0.1
#     Uninstalling eye-ai-0.0.1:
#       Successfully uninstalled eye-ai-0.0.1
#   Attempting uninstall: deriva-ml
#     Found existing installation: deriva-ml 0.0.1
#     Uninstalling deriva-ml-0.0.1:
#       Successfully uninstalled deriva-ml-0.0.1
#   Attempting uninstall: charset-normalizer
#     Found existing installation: charset-normalizer 3.3.2
#     Uninstalling charset-normalizer-3.3.2:
#       Successfully uninstalled charset-normalizer-3.3.2
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2024.2.2
#     Uninstalling certifi-2024.2.2:
#       Successfully uninstalled certifi-2024.2.2
#   Attempting uninstall: attrs
#     Found existing installation: attrs 23.2.0
#     Uninstalling attrs-23.2.0:
#       Successfully uninstalled attrs-23.2.0
#   Attempting uninstall: annotated-types
#     Found existing installation: annotated-types 0.6.0
#     Uninstalling annotated-types-0.6.0:
#       Successfully uninstalled annotated-types-0.6.0
#   Attempting uninstall: setuptools_scm
#     Found existing installation: setuptools-scm 5.0.2
#     Uninstalling setuptools-scm-5.0.2:
#       Successfully uninstalled setuptools-scm-5.0.2
#   Attempting uninstall: requests
#     Found existing installation: requests 2.31.0
#     Uninstalling requests-2.31.0:
#       Successfully uninstalled requests-2.31.0
#   Attempting uninstall: referencing
#     Found existing installation: referencing 0.33.0
#     Uninstalling referencing-0.33.0:
#       Successfully uninstalled referencing-0.33.0
#   Attempting uninstall: pydantic-core
#     Found existing installation: pydantic_core 2.16.2
#     Uninstalling pydantic_core-2.16.2:
#       Successfully uninstalled pydantic_core-2.16.2
#   Attempting uninstall: cffi
#     Found existing installation: cffi 1.16.0
#     Uninstalling cffi-1.16.0:
#       Successfully uninstalled cffi-1.16.0
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.6.1
#     Uninstalling pydantic-2.6.1:
#       Successfully uninstalled pydantic-2.6.1
#   Attempting uninstall: jsonschema-specifications
#     Found existing installation: jsonschema-specifications 2023.12.1
#     Uninstalling jsonschema-specifications-2023.12.1:
#       Successfully uninstalled jsonschema-specifications-2023.12.1
#   Attempting uninstall: cryptography
#     Found existing installation: cryptography 42.0.3
#     Uninstalling cryptography-42.0.3:
#       Successfully uninstalled cryptography-42.0.3
#   Attempting uninstall: bagit-profile
#     Found existing installation: bagit-profile 1.3.1
#     Uninstalling bagit-profile-1.3.1:
#       Successfully uninstalled bagit-profile-1.3.1
#   Attempting uninstall: jsonschema
#     Found existing installation: jsonschema 4.21.1
#     Uninstalling jsonschema-4.21.1:
#       Successfully uninstalled jsonschema-4.21.1
#   Attempting uninstall: bdbag
#     Found existing installation: bdbag 1.7.2
#     Uninstalling bdbag-1.7.2:
#       Successfully uninstalled bdbag-1.7.2
#   Attempting uninstall: globus_sdk
#     Found existing installation: globus-sdk 3.37.0
#     Uninstalling globus-sdk-3.37.0:
#       Successfully uninstalled globus-sdk-3.37.0
#   Attempting uninstall: fair-research-login
#     Found existing installation: fair-research-login 0.3.1
#     Uninstalling fair-research-login-0.3.1:
#       Successfully uninstalled fair-research-login-0.3.1
#   Attempting uninstall: fair-identifiers-client
#     Found existing installation: fair-identifiers-client 0.5.1
#     Uninstalling fair-identifiers-client-0.5.1:
#       Successfully uninstalled fair-identifiers-client-0.5.1
#   Attempting uninstall: deriva
#     Found existing installation: deriva 1.6.4
#     Uninstalling deriva-1.6.4:
#       Successfully uninstalled deriva-1.6.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# Successfully installed annotated-types-0.6.0 attrs-23.2.0 bagit-1.8.1 bagit-profile-1.3.1 bdbag-1.7.2 certifi-2024.2.2 cffi-1.16.0 charset-normalizer-3.3.2 cryptography-42.0.3 deriva-1.6.4 deriva-ml-0.0.1 eye-ai-0.0.1 eye-ai-ml-0.0.1 fair-identifiers-client-0.5.1 fair-research-login-0.3.1 globus_sdk-3.37.0 idna-3.6 jsonschema-4.21.1 jsonschema-specifications-2023.12.1 packaging-23.2 pika-1.3.2 portalocker-2.8.2 pycparser-2.21 pydantic-2.6.1 pydantic-core-2.16.2 pyjwt-2.8.0 pytz-2024.1 referencing-0.33.0 requests-2.31.0 rpds-py-0.18.0 setuptools-69.1.0 setuptools_scm-5.0.2 six-1.16.0 typing-extensions-4.9.0 tzlocal-5.2 urllib3-1.26.18

# %%
# @title login to DERIVA via Globus Auth

DEBUG_MODE = True #@param ["False", "True"] {type:"raw"}
catalog_id = "eye-ai" #@param
DEFAULT_SERVER = 'dev.eye-ai.org' if DEBUG_MODE else 'www.eye-ai.org'

# !deriva-globus-auth-utils login --no-browser --host {DEFAULT_SERVER}

# %%
EA = EyeAI(hostname = DEFAULT_SERVER, catalog_id = catalog_id, data_dir="test/")
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s', force=True)

# %%
# @title Initiate an Execution
configuration_records = EA.execution_init(configuration_rid="2-5Q3R")
configuration_records

# %%
# @title Get cropped images from the raw image and svg bounding box
cropped_path, output_csv = EA.get_crop_image(bag_path=configuration_records['bag_paths'][0],
                                             crop_to_eye=True)
